# %% [markdown]
# # Portfolio Optimization with Multiple Regression

# %% [markdown]
# ### Imports

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Collection and Manipulation

# %% [markdown]
# Randomly chosen tickers (approximately 100)

# %%
technology = ["GOOGL", "TSLA", "AAPL", "MSFT", "NVDA", "INTC", "ADBE", "CRM", "IBM"]
consumer_discretionary = ["HD", "NKE", "MCD", "SBUX", "TGT", "LOW", "GM", "F"]
communication_services = ["META", "NFLX", "DIS", "CMCSA", "CHTR", "T", "VZ"]
consumer_staples = ["PG", "WMT", "KO", "PEP", "COST", "CL", "MDLZ", "KHC", "PM", "MO"]
energy = ["XOM", "CVX", "COP", "SLB", "KMI", "OXY", "PSX", "MPC", "EOG"]
financials = ["JPM", "BAC", "WFC", "C", "GS", "MS", "AXP", "V", "MA"]
healthcare = ["JNJ", "PFE", "MRK", "UNH", "ABT", "AMGN", "BMY", "MDT", "TMO"]
industrials = ["BA", "HON", "UPS", "MMM", "CAT", "UNP", "GE", "FDX", "RTX", "LMT"]
materials = ["ECL", "DD", "LIN", "SHW", "APD", "NEM", "FCX", "IP"]
real_estate = ["AMT", "PLD", "SPG", "CCI", "EQR", "PSA", "AVB", "O", "DLR"]
utilities = ["NEE", "DUK", "D", "SO", "AEP", "EXC", "ED", "SRE", "PEG"]

# %%
tickers = [technology, consumer_discretionary, communication_services, consumer_staples,
          energy, financials, healthcare, industrials, materials, real_estate, utilities]

# %% [markdown]
# #### Check if 'tickers' list has Multiple Occurances and Convert to Single Occurances

# %%
def check_ticker_occurances():
    # O(n) complexity
    for itr in range(len(tickers)):        
        # use set data structure to check for uniques
        if(len(set(tickers[itr])) != len(tickers[itr])):
            return True
    return False

def remove_multiple_ticker_occurances():
    # O(n) time complexity
    for itr in range(len(tickers)):
        if(len(set(tickers[itr])) != len(tickers[itr])):
            tickers[itr] = list(set(tickers[itr]))
    print(f'Removed Multiple Occurances of Tickers!')

if check_ticker_occurances():
    print(f'Multiple occurances of tickers found!')
    remove_multiple_ticker_occurances()
else:
    print(f'Single Occurances found!')
# Out:
# Single Occurances found!

# %% [markdown]
# #### Download 6 years of Daily stock data from Yahoo Finance

# %%
# temp = yf.download(technology, start="2018-01-01", end="2024-01-01")["Adj Close"].resample('W').last()

# %%
data_technology = yf.download(technology, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_consumer_discretionary = yf.download(consumer_discretionary, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_communication_services = yf.download(communication_services, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_consumer_staples = yf.download(consumer_staples, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_energy = yf.download(energy, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_financials = yf.download(financials, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_healthcare = yf.download(healthcare, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_industrials = yf.download(industrials, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_materials = yf.download(materials, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_real_estate = yf.download(real_estate, start="2020-01-01", end="2024-01-01")["Adj Close"]
data_utilities = yf.download(utilities, start="2020-01-01", end="2024-01-01")["Adj Close"]
# Out:
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  8 of 8 completed
# [*********************100%%**********************]  7 of 7 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  8 of 8 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  9 of 9 completed

# %%
data_tickers = [data_technology, data_consumer_discretionary, data_communication_services, data_consumer_staples, 
               data_energy, data_financials, data_healthcare, data_industrials, data_materials, data_real_estate, data_utilities]

# %% [markdown]
# #### Download weekly data

# %%
data_technology_weekly = yf.download(technology, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_consumer_discretionary_weekly = yf.download(consumer_discretionary, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_communication_services_weekly = yf.download(communication_services, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_consumer_staples_weekly = yf.download(consumer_staples, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_energy_weekly = yf.download(energy, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_financials_weekly = yf.download(financials, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_healthcare_weekly = yf.download(healthcare, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_industrials_weekly = yf.download(industrials, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_materials_weekly = yf.download(materials, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_real_estate_weekly = yf.download(real_estate, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
data_utilities_weekly = yf.download(utilities, start="2020-01-01", end="2024-01-01")["Adj Close"].resample('W').last()
# Out:
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  8 of 8 completed
# [*********************100%%**********************]  7 of 7 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  8 of 8 completed
# [*********************100%%**********************]  9 of 9 completed
# [*********************100%%**********************]  9 of 9 completed

# %%
data_tickers_weekly = [data_technology_weekly, data_consumer_discretionary_weekly, data_communication_services_weekly, 
                       data_consumer_staples_weekly, data_energy_weekly, data_financials_weekly, data_healthcare_weekly, 
                       data_industrials_weekly, data_materials_weekly, data_real_estate_weekly, data_utilities_weekly]

# %% [markdown]
# #### Check Five-Point Statistics of the Technology Sector

# %%
data_technology.describe()

# %% [markdown]
# #### Visualize Each Sector Data

# %%
tech_plt = data_technology.plot(figsize = (10, 7.5))
tech_plt.set_xlabel("Year")
tech_plt.set_ylabel("Stock Value")

# %%
finance_plt = data_financials.plot(figsize = (10, 7.5))
finance_plt.set_xlabel("Year")
finance_plt.set_ylabel("Stock Value")

# %%
fig, axes = plt.subplots(nrows = 6, ncols = 2, figsize = (10, 20))

data_technology.plot(ax = axes[0][0], title = 'Technology Sector', legend = True)
data_consumer_discretionary.plot(ax=axes[0][1], title = 'Consumer Discretionary', legend = True)
data_communication_services.plot(ax = axes[1][0], title = 'Communication Services', legend = True)
data_consumer_staples.plot(ax=axes[1][1], title = 'Consumer Staples', legend = True)
data_energy.plot(ax = axes[2][0], title = 'Energy', legend = True)
data_financials.plot(ax=axes[2][1], title = 'Financials', legend = True)
data_healthcare.plot(ax = axes[3][0], title = 'Healthcare', legend = True)
data_industrials.plot(ax=axes[3][1], title = 'Industrials', legend = True)
data_materials.plot(ax = axes[4][0], title = 'Materials', legend = True)
data_real_estate.plot(ax=axes[4][1], title = 'Real Estate', legend = True)
data_utilities.plot(ax = axes[5][0], title = 'Utilities', legend = True)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### 1. Calculate weekly log returns

# %%
data_weekly_log_returns = []

# Always keep the sector order in ALL lists maintained

def calc_log_returns():    
    for sector in data_tickers_weekly:
        new_df = pd.DataFrame()
        new_df = sector.apply(lambda x: np.log(x) - np.log(x.shift(1)))
        new_df = new_df.iloc[1:]
        data_weekly_log_returns.append(new_df)

calc_log_returns()

# %%
data_log_retuns0_plt = data_weekly_log_returns[0]["AAPL"].plot(figsize = (10, 7.5))
data_log_retuns0_plt.set_xlabel("Year")
data_log_retuns0_plt.set_ylabel("Stock Value")

# %%
data_weekly_log_returns[0].describe()

# %% [markdown]
# #### 2. Calculate weekly P/E ratio

# %%
# !! This Code Block is not being used !! #

data_eps = []

def eps():

    '''function to find earnings per share (eps) of tickers'''
    
    for sector in tickers:
        year_2023, year_2022, year_2021, year_2020 = [], [], [], []
        for ticker in sector:
            ticker_financials = yf.Ticker(ticker).financials.T["Basic EPS"]
            year_2023.append(ticker_financials[0]/52)
            year_2022.append(ticker_financials[1]/52)
            year_2021.append(ticker_financials[2]/52)
            year_2020.append(ticker_financials[3]/52)
        dict = {"Ticker": sector, "2023-09-30": year_2023, "2022-09-30": year_2022, "2021-09-30": year_2021, "2020-09-30": year_2020}
        data_eps.append(pd.DataFrame(dict).set_index("Ticker").T)
    return None

eps()

# %%
# Ticker Order Has Been Changed Here!

data_eps_mean = []

def eps_mean():

    '''function to find earnings per share (eps) of tickers'''
    
    for sector in tickers:
        eps_ticker = []
        for ticker in sector:
            # Mean eps value of 4 years
            ticker_financials_eps_mean = yf.Ticker(ticker).financials.T["Basic EPS"].sum() / 4
            # Weekly eps value over 4 years
            ticker_financials_eps_mean_weekly = ticker_financials_eps_mean / 52
            eps_ticker.append(ticker_financials_eps_mean_weekly)
        dict = {"Ticker": sector, "EPS": eps_ticker}
        data_eps_mean.append(pd.DataFrame(dict).set_index("Ticker").T)
    return None

eps_mean()

# %% [markdown]
# #### Replace NaN values by 0

# %%
for sector in data_eps_mean:
    sector.fillna(0, inplace = True)

# %%
data_pe_ratio = data_tickers_weekly

def pe_ratio():

    '''function to calculate weekly P/E ratio'''
    for itr in range(len(data_pe_ratio)):
        data_pe_ratio[itr] = pd.concat([data_pe_ratio[itr], data_eps_mean[itr]], axis = 0)
        eps_row = data_pe_ratio[itr].iloc[-1]
        data_pe_ratio[itr] = data_pe_ratio[itr].div(eps_row, axis = 1)
        data_pe_ratio[itr] = data_pe_ratio[itr].iloc[:-1]
    return None

pe_ratio()

# %% [markdown]
# #### 3. Calculate Beta

# %%
data_sp500 = yf.download("^GSPC", start = "2020-01-01", end = "2024-01-01")["Adj Close"].resample('W').last()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Weekly Returns of S&P500

weekly_returns_sp500 = data_sp500.pct_change()

# %%
# Variance of S&P500

variance_sp500 = data_sp500.pct_change().var()

# %%
weekly_returns_individual_stocks = []

def weekly_returns():

    '''function to calculate weekly returns of tickers'''
    
    for sector in data_tickers_weekly:
        new_df = pd.DataFrame()
        for ticker in list(sector.columns):
            new_df[ticker] = sector[ticker].pct_change() 
            new_df = new_df.iloc[1:]
        weekly_returns_individual_stocks.append(new_df)
    return None

weekly_returns()

# %%
data_beta = []

def beta():

    '''function to calculate beta values of tickers'''
    
    for sector in range(len(weekly_returns_individual_stocks)):
        beta_tickers = []
        for ticker in list(weekly_returns_individual_stocks[sector].columns):
            # calculate covariance
            covariance = weekly_returns_individual_stocks[sector][ticker].cov(weekly_returns_sp500)
            # calculate beta value
            beta = covariance / variance_sp500
            beta_tickers.append(beta)
        tickers = list(weekly_returns_individual_stocks[sector].columns)
        dict = {"Ticker": tickers, "Beta": beta_tickers}
        data_beta.append(pd.DataFrame(dict))
    return None
    
beta()

# %%
data_beta[0]
# Out:
#   Ticker      Beta
# 0   AAPL  1.032289
# 1   ADBE  1.145700
# 2    CRM  1.168389
# 3  GOOGL  0.970777
# 4    IBM  0.766877
# 5   INTC  0.980223
# 6   MSFT  0.909093
# 7   NVDA  1.477303
# 8   TSLA  1.862068

# %% [markdown]
# #### Calculate Weekly Beta

# %% [markdown]
# #### 4. Correlation between Assets

# %%
data_correlation_matrix = []

def corr_matrix():
    for sector in data_tickers:
        data_correlation_matrix.append(sector.corr())

corr_matrix()

# %%
data_correlation_matrix[0]

# %%
sns.heatmap(data_correlation_matrix[0], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
type(data_correlation_matrix[0])

# %% [markdown]
# ## Regression Analysis

# %%
data = pd.DataFrame() 
data[]
x = sm.add_constant(

# %%
dict = {'Ticker': list((correlation_matrix.index)), 'Correlation_PCA': reduced_vector}
correlation_pca_matrix = pd.DataFrame(dict)

# %%
independent_features = log_returns
independent_features = independent_features.T

# %%
independent_features.reset_index(inplace=True)  # Reset index and make the current index a normal column
independent_features.rename(columns={'index': 'Ticker'}, inplace=True)  # Rename the old index column if needed
independent_features.index = range(1, len(independent_features) + 1)  # Set new index column with serial numbers starting from 1
independent_features.head()

# %% [markdown]
# #### Inner Joins

# %%
independent_features = pd.merge(independent_features, PE_data, how ='inner', on ='Ticker')
independent_features = pd.merge(independent_features, betas, how ='inner', on ='Ticker')
independent_features = pd.merge(independent_features, correlation_pca_matrix, how ='inner', on ='Ticker')

# %%
independent_features.head()

# %%
X = independent_features
Y = daily_returns_individual_stocks.T

X

# %%
Y

# %%
X = independent_features
Y = daily_returns_individual_stocks.T

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model (for demonstration purposes)
score = model.score(X_test, y_test)
print("R-squared score:", score)

# X = sm.add_constant(X)  # Add constant term
# model = sm.OLS(y, X).fit()  # Fit regression model
# print(model.summary())  # Display regression summary

# %% [markdown]
# ## Correlation between stocks in each sector

# %%
data_correlation_matrix = []

def correlation_matrix():
    for sector in data_tickers:
        data_correlation_matrix.append(sector.corr())

correlation_matrix()

# %%
sns.heatmap(data_correlation_matrix[0], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[1], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[2], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[3], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[4], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[5], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[6], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[7], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[8], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[9], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix[10], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Sector most closely related to S&P500

# %% [markdown]
# #### Add S&P500 data to dataframes

# %%
corr_data_tickers = data_tickers_weekly

for i in range(len(corr_data_tickers)):
    corr_data_tickers[i]["SP500"] = data_sp500

# %%
data_correlation_matrix_sp500 = []

def correlation_matrix_sp500():
    for sector in corr_data_tickers:
        data_correlation_matrix_sp500.append(sector.corr())

correlation_matrix_sp500()

# %%
sns.heatmap(data_correlation_matrix_sp500[0], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[1], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[2], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[3], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[4], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[5], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[6], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[7], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[8], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[9], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

sns.heatmap(data_correlation_matrix_sp500[10], annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
correlation_sector_values = []

for itr in range(11):
    correlation_sector_values.append(data_correlation_matrix_sp500[itr]["SP500"].sum())

# %%
max_correlation_value = max(correlation_sector_values)

for itr in range(len(correlation_sector_values)):
    if max_correlation_value == correlation_sector_values[itr]:
        print(itr)

print(data_correlation_matrix_sp500[3])
# Out:
# 3
# Ticker        CL      COST       KHC        KO      MDLZ        MO       PEP  \
# Ticker
# CL      1.000000  0.540249  0.671076  0.572735  0.620555  0.514141  0.535517
# COST    0.540249  1.000000  0.667188  0.837076  0.836448  0.769492  0.883862
# KHC     0.671076  0.667188  1.000000  0.762813  0.723539  0.845795  0.732595
# KO      0.572735  0.837076  0.762813  1.000000  0.865463  0.862942  0.934817
# MDLZ    0.620555  0.836448  0.723539  0.865463  1.000000  0.786220  0.924263
# MO      0.514141  0.769492  0.845795  0.862942  0.786220  1.000000  0.808574
# PEP     0.535517  0.883862  0.732595  0.934817  0.924263  0.808574  1.000000
# PG      0.707889  0.884331  0.709031  0.846232  0.886872  0.802963  0.870290
# PM      0.580415  0.835633  0.828963  0.912871  0.859305  0.920127  0.879899
# WMT     0.590045  0.757694  0.585029  0.576722  0.795155  0.601363  0.699554
# SP500   0.697592  0.815790  0.721187  0.681269  0.749947  0.784457  0.690085
#
# ...

# %% [markdown]
# ### The sector with maximum correlation with S&P500 is the Consumer Staples Sector
